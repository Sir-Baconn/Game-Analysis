# %%
import numpy as np
import pandas as pd
from os import path
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, ImageColorGenerator
import random

# %%
df = pd.read_csv('youtube-new/USvideos.csv')
df
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# 5      gHZ1Qz0KiKM      17.14.11
# 6      39idVpFF7NQ      17.14.11
# 7      nc99ccSXST0      17.14.11
# 8      jr9QtXwC9vc      17.14.11
# 9      TUmyygCMMGA      17.14.11
# 10     9wRQljFNDW8      17.14.11
# 11     VifQlJit6A0      17.14.11
# 12     5E4ZBSInqUU      17.14.11
# 13     GgVmn66oK_A      17.14.11
# 14     TaTleo4cOs8      17.14.11
# 15     kgaO45SyaO4      17.14.11
# 16     ZAQs-ctOqXQ      17.14.11
# 17     YVfyYrEmzgM      17.14.11
# 18     eNSN6qet1kE      17.14.11
# 19     B5HORANmzHw      17.14.11
# 20     vU14JY3x81A      17.14.11
# 21     6VhU_T463sU      17.14.11
# 22     _-aDHxoblr4      17.14.11
# 23     JBZTZZAcFTw      17.14.11
# 24     lZ68j2J_GOM      17.14.11
# 25     dRpNZV18N_g      17.14.11
# 26     fcVjitaM3LY      17.14.11
# ...

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(%d, %d%%, %d%%)" % (random.randint(0, 12), random.randint(50, 100), random.randint(30, 60))

# %%
mask = np.array(Image.open(path.join("imgs", "youtube_mask.png")))
wc = WordCloud(max_words=4000, mask=mask, margin=10, max_font_size=100, width=800, height=400,
               random_state=1).generate(' '.join(df['title']))
wc.to_file("youtube_title_cloud.png")
# youtube_coloring = np.array(Image.open(path.join("imgs", "youtube_mask.png")))
image_colors = ImageColorGenerator(youtube_coloring)

# %%
# plt.imshow(wc, interpolation='bilinear')
plt.figure(figsize=(20,10))
plt.imshow(wc.recolor(color_func=grey_color_func), interpolation="bilinear")
plt.axis("off")
# Out:
# (-0.5, 1856.5, 858.5, -0.5)
